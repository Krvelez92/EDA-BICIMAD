# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# ¿Es BICIMAD eficiente?

# %% [markdown]
# ### TEMA

# %% [markdown]
# Queremos descubrir que tan útil y eficiente es Bicimad, estudiar su estacionalidad y comportamiento para ver si las estaciones están bien ubicadas para una movilidad más activa y sostenible.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# - Primera Hipótesis: las estaciones están ubicadas en sitios clave con alto aforo de personas.
# - Segunda Hipótesis: Existe buena disponibilidad de bicicletas en horas pico.
# - Tercera Hipótesis: Las bicicletas se usan para hacer turismo.
# - Cuanta Hipótesis: Las bicicletas se usan más los fines de semana que entre semana.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
usuarios_bici_resumen_2022 = pd.read_csv('./data/Datos Tratados/usuarios_bici_resumen_2022.csv')
uso_bici_resumen_2022 = pd.read_csv('./data/Datos Tratados/uso_bici_resumen_2022.csv')
fuente_1 = "https://datos.madrid.es/sites/v/index.jsp?vgnextoid=6d8bdae2be63c410VgnVCM1000000b205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD"

sit_estaciones_2022 = pd.read_csv('./data/Datos Tratados/sit_estaciones_2022.csv')
fuente_2 = "https://datos.madrid.es/sites/v/index.jsp?vgnextoid=f4b07e0543815610VgnVCM1000001d4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD"

intinerarios_bicicletas_2022 = pd.read_csv('./data/Datos Tratados/intinerarios_bicicletas_2022.csv')
fuente_3 = "https://datos.madrid.es/sites/v/index.jsp?vgnextoid=d67921bb86e64610VgnVCM2000001f4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD"

mapa_bases_bicicletas = pd.read_csv('./data/Datos Tratados/mapa_bases_bicicletas.csv')
fuente_4 = "https://datos.madrid.es/sites/v/index.jsp?vgnextoid=e9b2a4059b4b7410VgnVCM2000000c205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD"

dispo_bicis_2022 = pd.read_csv('./data/Datos Tratados/dispo_bicis_2022.csv')
fuente_5 = "https://datos.madrid.es/sites/v/index.jsp?vgnextoid=7547ff52e4a4f410VgnVCM1000000b205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD"

aforo_bicicletas_2022 = pd.read_csv('./data/Datos Tratados/aforo_bicicletas_2022.csv')
aforo_personas_2022 = pd.read_csv('./data/Datos Tratados/aforo_personas_2022.csv')
fuente_6 = "https://datos.madrid.es/sites/v/index.jsp?vgnextoid=695cd64d6f9b9610VgnVCM1000001d4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD"
# Out:
# C:\Users\karli\AppData\Local\Temp\ipykernel_24176\2665758315.py:10: DtypeWarning: Columns (5,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   intinerarios_bicicletas_2022 = pd.read_csv('./data/Datos Tratados/intinerarios_bicicletas_2022.csv')

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
usuarios_bici_resumen_2022.head()
# Out:
#    anio  mes       fecha  alta_ab_anual_dia  alta_ab_anual_mes  \
# 0  2022    1  2022-01-01              -16.0              -16.0
# 1  2022    1  2022-01-02               19.0                3.0
# 2  2022    1  2022-01-03               15.0               18.0
# 3  2022    1  2022-01-04              -27.0               -9.0
# 4  2022    1  2022-01-05              -37.0              -46.0
#
#    alta_ab_1d_dia  alta_ab_3d_dia  alta_ab_5d_dia  alta_ab_ocas_dia  \
# 0            36.0             4.0             1.0              41.0
# 1            22.0             1.0             0.0              23.0
# 2            12.0             1.0             2.0              15.0
# 3             2.0             0.0             0.0               2.0
# 4             3.0             0.0             0.0               3.0
#
#    alta_ab_1d_mes  alta_ab_3d_mes  alta_ab_5d_mes  alta_ab_ocas_mes
# 0            36.0             4.0             1.0              41.0
# ...

# %%
uso_bici_resumen_2022.head()
# Out:
#    anio  mes       fecha  uso_ab_anual_dia  uso_ab_ocas_dia  uso_ab_total_dia  \
# 0  2022    1  2022-01-01            3061.0             69.0            3130.0
# 1  2022    1  2022-01-02            3824.0             42.0            3866.0
# 2  2022    1  2022-01-03            5600.0             20.0            5620.0
# 3  2022    1  2022-01-04            5054.0             14.0            5068.0
# 4  2022    1  2022-01-05            3231.0             10.0            3241.0
#
#    uso_ab_anual_mes  uso_ab_ocas_mes  uso_ab_total_mes
# 0            3061.0             69.0            3130.0
# 1            6885.0            111.0            6996.0
# 2           12485.0            131.0           12616.0
# 3           17539.0            145.0           17684.0
# 4           20770.0            155.0           20925.0

# %%
sit_estaciones_2022.head()
# Out:
#                    fecha_hora  id_estacion cod_estacion        des_estacion  \
# 0  2022-01-01T00:13:20.603583            1           1a    Puerta del Sol A
# 1  2022-01-01T00:13:20.603583            2           1b    Puerta del Sol B
# 2  2022-01-01T00:13:20.603583            3            2         Miguel Moya
# 3  2022-01-01T00:13:20.603583            4            3  Plaza Conde Suchil
# 4  2022-01-01T00:13:20.603583            5            4            Malasaña
#
#    activate  light  total_bases  free_bases  dock_bikes  reservations_count
# 0         1      3           30           0           0                   0
# 1         1      3           30           0           0                   0
# 2         1      0           24          16           7                   0
# 3         1      1           18           1          14                   0
# 4         1      1           24           2          17                   0

# %%
intinerarios_bicicletas_2022.head()
# Out:
#         fecha  trip_minutes          unlock_date  lon_unlock  lat_unlock  \
# 0  2022-01-01         16.28  2022-01-01T00:02:20   -3.671417   40.431861
# 1  2022-01-01          7.10  2022-01-01T00:07:53   -3.689419   40.416683
# 2  2022-01-01          0.48  2022-01-01T00:09:21   -3.688822   40.409808
# 3  2022-01-01          6.62  2022-01-01T00:09:52   -3.665306   40.426000
# 4  2022-01-01          8.07  2022-01-01T00:09:57   -3.698306   40.396222
#
#   station_unlock  dock_unlock     unlock_station_name            lock_date  \
# 0          200.0          3.0  Avenida de los Toreros  2022-01-01T00:18:37
# 1           69.0          5.0           Antonio Maura  2022-01-01T00:14:59
# 2           73.0         21.0  Puerta del Ángel Caído  2022-01-01T00:09:50
# 3          192.0         22.0        Marqués de Zafra  2022-01-01T00:16:29
# 4          183.0          3.0   Jaime el Conquistador  2022-01-01T00:18:01
#
# ...

# %%
mapa_bases_bicicletas.head()
# Out:
#   Número Fecha de Alta       Distrito           Barrio  \
# 0  106 a    2014-05-23  04  SALAMANCA  04-01 RECOLETOS
# 1    104    2014-06-23  04  SALAMANCA  04-01 RECOLETOS
# 2     92    2014-06-23  04  SALAMANCA  04-01 RECOLETOS
# 3     91    2014-06-23  04  SALAMANCA       04-02 GOYA
# 4     90    2014-06-23  04  SALAMANCA  04-01 RECOLETOS
#
#                        Calle Nº Finca Tipo de Reserva  Número de Plazas  \
# 0         SERRANO, CALLE, DE       32         BiciMAD                18
# 1   CASTELLANA, PASEO, DE LA        4         BiciMAD                21
# 2  CLAUDIO COELLO, CALLE, DE       45         BiciMAD                24
# 3      HERMOSILLA, CALLE, DE       73         BiciMAD                24
# 4            GOYA, CALLE, DE       18         BiciMAD                24
#
#    Longitud    Latitud                      Direccion
# 0 -3.687887  40.424864         SERRANO, CALLE, DE, 32
# 1 -3.689579  40.426766    CASTELLANA, PASEO, DE LA, 4
# ...

# %%
dispo_bicis_2022.head()
# Out:
#           DIA HORAS_TOTALES_USOS_BICICLETAS  \
# 0  10/08/2015                      3.991,13
# 1  11/08/2015                      4.364,40
# 2  12/08/2015                      4.633,72
# 3  13/08/2015                      4.498,85
# 4  14/08/2015                      4.309,22
#
#   HORAS_TOTALES_DISPONIBILIDAD_BICICLETAS_EN _ANCLAJES  \
# 0                                          19.894,18
# 1                                          19.817,30
# 2                                          19.725,32
# 3                                          19.530,97
# 4                                          22.770,43
#
#   TOTAL_HORAS_SERVICIO_BICICLETAS MEDIA_BICICLETAS_DISPONIBLES  \
# 0                       23.885,31                       995,22
# 1                       24.181,70                     1.007,57
# 2                       24.359,04                     1.014,96
# 3                       24.029,82                     1.001,24
# ...

# %%
aforo_bicicletas_2022.head()
# Out:
#              fecha  bicicletas                        direccion    latitude  \
# 0  01/09/2022 0:00           5  Calle Toledo  133, 28005 Madrid  40.405.472
# 1  01/09/2022 1:00           3  Calle Toledo  133, 28005 Madrid  40.405.472
# 2  01/09/2022 2:00           1  Calle Toledo  133, 28005 Madrid  40.405.472
# 3  01/09/2022 3:00           1  Calle Toledo  133, 28005 Madrid  40.405.472
# 4  01/09/2022 4:00           0  Calle Toledo  133, 28005 Madrid  40.405.472
#
#     longitude
# 0  -3.711.961
# 1  -3.711.961
# 2  -3.711.961
# 3  -3.711.961
# 4  -3.711.961

# %%
aforo_personas_2022.head()
# Out:
#              fecha  peatones                          direccion    latitude  \
# 0  01/09/2022 0:00       136  Calle Fuencarral 22, 28004 Madrid  40.422.009
# 1  01/09/2022 1:00       129  Calle Fuencarral 22, 28004 Madrid  40.422.009
# 2  01/09/2022 2:00       138  Calle Fuencarral 22, 28004 Madrid  40.422.009
# 3  01/09/2022 3:00       244  Calle Fuencarral 22, 28004 Madrid  40.422.009
# 4  01/09/2022 4:00       527  Calle Fuencarral 22, 28004 Madrid  40.422.009
#
#     longitude
# 0  -3.700.892
# 1  -3.700.892
# 2  -3.700.892
# 3  -3.700.892
# 4  -3.700.892
